# %%
from quotegenerator import QuoteGenerator

q = QuoteGenerator()


for i in range(100):
    quote = q.generate_quote()
    print(f"{i}. {quote}")
# Out:
# EntityExtractor inicializado con Foundry, endpoint: https://ips-master-dev-agents-resource.cognitiveservices.azure.com, model: gpt-4o
# 0. Un erizo feliz preparando paella en una playa.
# 1. Un gato con bigote de chef cocinando churros en Montjuïc.
# 2. Un pingüino DJ mezclando música en la playa Barceloneta.
# 3. "Manuel, vestido de pirata, jugando al ping pong con un kiwi alegre."
# 4. "Arnau, disfrazado de astronauta, ordeñando una vaca en la Luna."
# 5. "Una abeja con gafas de sol pintando un grafiti de IPS."
# 6. "Una tortuga programadora con gafas trabajando en su laptop bajo un cocotero."
# 7. "Una ardilla científica mirando datos en su microscopio."
# 8. "Alba vestida de flamenca discutiendo con una naranja diabólica."
# 9. "Un caracol con corbata dando una presentación en PowerPoint."
# 10. "Josep montando en un dragón mientras come churros."
# 11. "Mayra, disfrazada de ninja, cortando un melón en BCN."
# ...
